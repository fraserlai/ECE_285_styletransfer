# %%
# %run -i 'main.py'
# Out:
# <data_utils.custom_dset object at 0x7f932a06d4a8>
# **********
# Epoch 1 / 1500
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:1749: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# main.py:57: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   loss += loss1.data[0]
# Loss : 0.020436, total_loss : 0.020436, Time:3.44 s
#
# **********
# Epoch 2 / 1500
# Loss : 0.019584, total_loss : 0.019584, Time:3.16 s
#
# **********
# Epoch 3 / 1500
# Loss : 0.019125, total_loss : 0.019125, Time:3.24 s
#
# **********
# Epoch 4 / 1500
# Loss : 0.018550, total_loss : 0.018550, Time:3.28 s
#
# **********
# Epoch 5 / 1500
# Loss : 0.018189, total_loss : 0.018189, Time:3.30 s
#
# **********
# Epoch 6 / 1500
# Loss : 0.017456, total_loss : 0.017456, Time:3.35 s
#
# **********
# Epoch 7 / 1500
# Loss : 0.016839, total_loss : 0.016839, Time:3.23 s
#
# **********
# Epoch 8 / 1500
# Loss : 0.016168, total_loss : 0.016168, Time:3.24 s
#
# **********
# Epoch 9 / 1500
# Loss : 0.015493, total_loss : 0.015493, Time:3.38 s
#
# **********
# Epoch 10 / 1500
# Loss : 0.014789, total_loss : 0.014789, Time:3.26 s
#
# **********
# Epoch 11 / 1500
# Loss : 0.014189, total_loss : 0.014189, Time:3.24 s
#
# **********
# Epoch 12 / 1500
# Loss : 0.013555, total_loss : 0.013555, Time:3.20 s
#
# **********
# Epoch 13 / 1500
# Loss : 0.013168, total_loss : 0.013168, Time:3.39 s
#
# **********
# Epoch 14 / 1500
# Loss : 0.013346, total_loss : 0.013346, Time:3.17 s
#
# **********
# Epoch 15 / 1500
# Loss : 0.013041, total_loss : 0.013041, Time:3.19 s
#
# **********
# Epoch 16 / 1500
# Loss : 0.012728, total_loss : 0.012728, Time:3.17 s
#
# **********
# Epoch 17 / 1500
# Loss : 0.012333, total_loss : 0.012333, Time:3.38 s
#
# **********
# Epoch 18 / 1500
# Loss : 0.012616, total_loss : 0.012616, Time:3.27 s
#
# **********
# Epoch 19 / 1500
# Loss : 0.012107, total_loss : 0.012107, Time:3.22 s
#
# **********
# Epoch 20 / 1500
# Loss : 0.012111, total_loss : 0.012111, Time:3.19 s
#
# **********
# Epoch 21 / 1500
# Loss : 0.011919, total_loss : 0.011919, Time:3.21 s
#
# **********
# Epoch 22 / 1500
# Loss : 0.012276, total_loss : 0.012276, Time:3.32 s
#
# **********
# Epoch 23 / 1500
# Loss : 0.011841, total_loss : 0.011841, Time:3.29 s
#
# **********
# Epoch 24 / 1500
# Loss : 0.011944, total_loss : 0.011944, Time:3.32 s
#
# **********
# Epoch 25 / 1500
# Loss : 0.011713, total_loss : 0.011713, Time:3.24 s
#
# **********
# Epoch 26 / 1500
# Loss : 0.011691, total_loss : 0.011691, Time:3.31 s
#
# **********
# Epoch 27 / 1500
# Loss : 0.011647, total_loss : 0.011647, Time:3.22 s
#
# **********
# Epoch 28 / 1500
# Loss : 0.011709, total_loss : 0.011709, Time:3.29 s
#
# **********
# Epoch 29 / 1500
# Loss : 0.011676, total_loss : 0.011676, Time:3.31 s
#
# **********
# Epoch 30 / 1500
# Loss : 0.011580, total_loss : 0.011580, Time:3.25 s
#
# **********
# Epoch 31 / 1500
# Loss : 0.011352, total_loss : 0.011352, Time:3.30 s
#
# **********
# Epoch 32 / 1500
# Loss : 0.011645, total_loss : 0.011645, Time:3.22 s
#
# **********
# Epoch 33 / 1500
# Loss : 0.011886, total_loss : 0.011886, Time:3.17 s
#
# **********
# Epoch 34 / 1500
# Loss : 0.011502, total_loss : 0.011502, Time:3.14 s
#
# **********
# Epoch 35 / 1500
# Loss : 0.011598, total_loss : 0.011598, Time:3.17 s
#
# **********
# Epoch 36 / 1500
# Loss : 0.011327, total_loss : 0.011327, Time:3.18 s
#
# **********
# Epoch 37 / 1500
# Loss : 0.011297, total_loss : 0.011297, Time:3.30 s
#
# **********
# Epoch 38 / 1500
# Loss : 0.011324, total_loss : 0.011324, Time:3.31 s
#
# **********
# Epoch 39 / 1500
# Loss : 0.011311, total_loss : 0.011311, Time:3.21 s
#
# **********
# Epoch 40 / 1500
# Loss : 0.011674, total_loss : 0.011674, Time:3.35 s
#
# **********
# Epoch 41 / 1500
# Loss : 0.011472, total_loss : 0.011472, Time:3.17 s
#
# **********
# Epoch 42 / 1500
# Loss : 0.011221, total_loss : 0.011221, Time:3.21 s
#
# **********
# Epoch 43 / 1500
# Loss : 0.011218, total_loss : 0.011218, Time:3.34 s
#
# **********
# Epoch 44 / 1500
# Loss : 0.011213, total_loss : 0.011213, Time:3.21 s
#
# **********
# Epoch 45 / 1500
# Loss : 0.011240, total_loss : 0.011240, Time:3.22 s
#
# **********
# Epoch 46 / 1500
# Loss : 0.011442, total_loss : 0.011442, Time:3.22 s
#
# **********
# Epoch 47 / 1500
# Loss : 0.011174, total_loss : 0.011174, Time:3.19 s
#
# **********
# Epoch 48 / 1500
# Loss : 0.011040, total_loss : 0.011040, Time:3.26 s
#
# **********
# Epoch 49 / 1500
# Loss : 0.011160, total_loss : 0.011160, Time:3.31 s
#
# **********
# Epoch 50 / 1500
# Loss : 0.011229, total_loss : 0.011229, Time:3.22 s
#
# **********
# Epoch 51 / 1500
# Loss : 0.011128, total_loss : 0.011128, Time:3.13 s
#
# **********
# Epoch 52 / 1500
# Loss : 0.011326, total_loss : 0.011326, Time:3.30 s
#
# **********
# Epoch 53 / 1500
# Loss : 0.011133, total_loss : 0.011133, Time:3.26 s
#
# **********
# Epoch 54 / 1500
# Loss : 0.010995, total_loss : 0.010995, Time:3.15 s
#
# **********
# Epoch 55 / 1500
# Loss : 0.010997, total_loss : 0.010997, Time:3.26 s
#
# **********
# Epoch 56 / 1500
# Loss : 0.010981, total_loss : 0.010981, Time:3.24 s
#
# **********
# Epoch 57 / 1500
# Loss : 0.011028, total_loss : 0.011028, Time:3.17 s
#
# **********
# Epoch 58 / 1500
# Loss : 0.010854, total_loss : 0.010854, Time:3.16 s
#
# **********
# Epoch 59 / 1500
# Loss : 0.010945, total_loss : 0.010945, Time:3.25 s
#
# **********
# Epoch 60 / 1500
# Loss : 0.010980, total_loss : 0.010980, Time:3.15 s
#
# **********
# Epoch 61 / 1500
# Loss : 0.011044, total_loss : 0.011044, Time:3.24 s
#
# **********
# Epoch 62 / 1500
# Loss : 0.011207, total_loss : 0.011207, Time:3.23 s
#
# **********
# Epoch 63 / 1500
# Loss : 0.011137, total_loss : 0.011137, Time:3.30 s
#
# **********
# Epoch 64 / 1500
# Loss : 0.011051, total_loss : 0.011051, Time:3.32 s
#
# **********
# Epoch 65 / 1500
# Loss : 0.010917, total_loss : 0.010917, Time:3.20 s
#
# **********
# Epoch 66 / 1500
# Loss : 0.010931, total_loss : 0.010931, Time:3.32 s
#
# **********
# Epoch 67 / 1500
# Loss : 0.011090, total_loss : 0.011090, Time:3.26 s
#
# **********
# Epoch 68 / 1500
# Loss : 0.010966, total_loss : 0.010966, Time:3.31 s
#
# **********
# Epoch 69 / 1500
# Loss : 0.011134, total_loss : 0.011134, Time:3.25 s
#
# **********
# Epoch 70 / 1500
# Loss : 0.010829, total_loss : 0.010829, Time:3.34 s
#
# **********
# Epoch 71 / 1500
# Loss : 0.011188, total_loss : 0.011188, Time:3.31 s
#
# **********
# Epoch 72 / 1500
# Loss : 0.010814, total_loss : 0.010814, Time:3.32 s
#
# **********
# Epoch 73 / 1500
# Loss : 0.010808, total_loss : 0.010808, Time:3.32 s
#
# **********
# Epoch 74 / 1500
# Loss : 0.011018, total_loss : 0.011018, Time:3.29 s
#
# **********
# Epoch 75 / 1500
# Loss : 0.010878, total_loss : 0.010878, Time:3.21 s
#
# **********
# Epoch 76 / 1500
# Loss : 0.010855, total_loss : 0.010855, Time:3.20 s
#
# **********
# Epoch 77 / 1500
# Loss : 0.010804, total_loss : 0.010804, Time:3.23 s
#
# **********
# Epoch 78 / 1500
# Loss : 0.010828, total_loss : 0.010828, Time:3.23 s
#
# **********
# Epoch 79 / 1500
# Loss : 0.010884, total_loss : 0.010884, Time:3.24 s
#
# **********
# Epoch 80 / 1500
# Loss : 0.010892, total_loss : 0.010892, Time:3.28 s
#
# **********
# Epoch 81 / 1500
# Loss : 0.010822, total_loss : 0.010822, Time:3.24 s
#
# **********
# Epoch 82 / 1500
# Loss : 0.010822, total_loss : 0.010822, Time:3.30 s
#
# **********
# Epoch 83 / 1500
# Loss : 0.010941, total_loss : 0.010941, Time:3.22 s
#
# **********
# Epoch 84 / 1500
# Loss : 0.010906, total_loss : 0.010906, Time:3.33 s
#
# **********
# Epoch 85 / 1500
# Loss : 0.010844, total_loss : 0.010844, Time:3.34 s
#
# **********
# Epoch 86 / 1500
# Loss : 0.010970, total_loss : 0.010970, Time:3.22 s
#
# **********
# Epoch 87 / 1500
# Loss : 0.010701, total_loss : 0.010701, Time:3.22 s
#
# **********
# Epoch 88 / 1500
# Loss : 0.010699, total_loss : 0.010699, Time:3.22 s
#
# **********
# Epoch 89 / 1500
# Loss : 0.010786, total_loss : 0.010786, Time:3.28 s
#
# **********
# Epoch 90 / 1500
# Loss : 0.011121, total_loss : 0.011121, Time:3.21 s
#
# **********
# Epoch 91 / 1500
# Loss : 0.011134, total_loss : 0.011134, Time:3.37 s
#
# **********
# Epoch 92 / 1500
# Loss : 0.011055, total_loss : 0.011055, Time:3.18 s
#
# **********
# Epoch 93 / 1500
# Loss : 0.010869, total_loss : 0.010869, Time:3.13 s
#
# **********
# Epoch 94 / 1500
# Loss : 0.010977, total_loss : 0.010977, Time:3.22 s
#
# **********
# Epoch 95 / 1500
# Loss : 0.010815, total_loss : 0.010815, Time:3.35 s
#
# **********
# Epoch 96 / 1500
# Loss : 0.010725, total_loss : 0.010725, Time:3.25 s
#
# **********
# Epoch 97 / 1500
# Loss : 0.010609, total_loss : 0.010609, Time:3.32 s
#
# **********
# Epoch 98 / 1500
# Loss : 0.010680, total_loss : 0.010680, Time:3.32 s
#
# **********
# Epoch 99 / 1500
# Loss : 0.010860, total_loss : 0.010860, Time:3.17 s
#
# **********
# Epoch 100 / 1500
# Loss : 0.010855, total_loss : 0.010855, Time:3.27 s
#
# **********
# Epoch 101 / 1500
# Loss : 0.010743, total_loss : 0.010743, Time:3.19 s
#
# **********
# Epoch 102 / 1500
# Loss : 0.010604, total_loss : 0.010604, Time:3.16 s
#
# **********
# Epoch 103 / 1500
# Loss : 0.010666, total_loss : 0.010666, Time:3.14 s
#
# **********
# Epoch 104 / 1500
# Loss : 0.010888, total_loss : 0.010888, Time:3.20 s
#
# **********
# Epoch 105 / 1500
# Loss : 0.010929, total_loss : 0.010929, Time:3.30 s
#
# **********
# Epoch 106 / 1500
# Loss : 0.010721, total_loss : 0.010721, Time:3.31 s
#
# **********
# Epoch 107 / 1500
# Loss : 0.010944, total_loss : 0.010944, Time:3.18 s
#
# **********
# Epoch 108 / 1500
# Loss : 0.010981, total_loss : 0.010981, Time:3.22 s
#
# **********
# Epoch 109 / 1500
# Loss : 0.010777, total_loss : 0.010777, Time:3.19 s
#
# **********
# Epoch 110 / 1500
# Loss : 0.010705, total_loss : 0.010705, Time:3.33 s
#
# **********
# Epoch 111 / 1500
# Process Process-442:
# Process Process-444:
# Process Process-443:
# Process Process-441:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/opt/conda/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/opt/conda/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/opt/conda/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/opt/conda/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterruptTraceback (most recent call last)
# ~/main.py in <module>()
#      99
#     100 if __name__ == "__main__":
# --> 101     main()
#     102
#
# ~/main.py in main()
#      94     train(epochs=1500, model=model, trainloader=trainloader,
#      95           crit=crit, optimizer=optimizer,scheduler=scheduler,
# ---> 96           save_step=20, weight_decay=weight_decay)
#      97
#      98     write.close()
#
# ~/main.py in train(epochs, model, trainloader, crit, optimizer, scheduler, save_step, weight_decay)
#      51
#      52             f_score, f_geometry = model(img)
# ---> 53             loss1 = crit(score_map, f_score, geo_map, f_geometry, training_mask)
#      54
#      55             to_loss = loss1 + weight_decay * L2_regularization(model)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/loss.py in forward(self, y_true_cls, y_pred_cls, y_true_geo, y_pred_geo, training_mask)
#      31                      y_true_geo, y_pred_geo,
#      32                              training_mask):
# ---> 33         classification_loss = dice_coefficient(y_true_cls, y_pred_cls, training_mask)
#      34         # scale classification loss to match the iou loss part
#      35         classification_loss *= 0.01
#
# ~/loss.py in dice_coefficient(y_true_cls, y_pred_cls, training_mask)
#      17     '''
#      18     eps = 1e-5
# ---> 19     intersection =torch.sum(y_true_cls * y_pred_cls * training_mask)
#      20     union = torch.sum(y_true_cls * training_mask) + torch.sum(y_pred_cls * training_mask) + eps
#      21     loss = 1. - (2 * intersection / union)
#
# KeyboardInterrupt:

# %%
import torch
from torch.autograd import Variable
import os 
from torch import nn
from torch.optim import lr_scheduler
from torch.nn.utils.rnn import pack_padded_sequence
from torch.utils.data import DataLoader
from torchvision import transforms
from model import East
from loss import *
from data_utils import custom_dset, collate_fn
import time
from tensorboardX import SummaryWriter



model = East()
model.load_state_dict(torch.load('./checkpoints_total/model_100.pth'))
model.eval()
model = model.cuda()

root_path = './dataset/'
train_img = root_path + 'train2015/'
train_txt = root_path + 'train_label/'


trainset = custom_dset(train_img, train_txt)
print(trainset)
trainloader = DataLoader(
                trainset, batch_size=16, shuffle=True, collate_fn=collate_fn, num_workers=4)
# Out:
# <data_utils.custom_dset object at 0x7f9329621ac8>
# RuntimeErrorTraceback (most recent call last)
# ~/main.py in <module>()
#      31                 trainset, batch_size=16, shuffle=True, collate_fn=collate_fn, num_workers=4)
#      32 for i, (img, score_map, geo_map, training_mask) in enumerate(trainloader):
# ---> 33     f_score, f_geometry = model(img)
#      34     break
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/model.py in forward(self, images)
#     222     def forward(self,images):
#     223         images = mean_image_subtraction(images)
# --> 224         _, f = self.resnet(images)
#     225         h = f[3]  # bs 2048 w/32 h/32
#     226         g = (self.unpool1(h)) #bs 2048 w/16 h/16
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/model.py in forward(self, x)
#     128     def forward(self, x):
#     129         f = []
# --> 130         x = self.conv1(x)
#     131         x = self.bn1(x)
#     132         x = self.relu(x)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     299     def forward(self, input):
#     300         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 301                         self.padding, self.dilation, self.groups)
#     302
#     303
#
# RuntimeError: Expected object of type torch.FloatTensor but found type torch.cuda.FloatTensor for argument #2 'weight'

# %%
for i, (img, score_map, geo_map, training_mask) in enumerate(trainloader):
    img = Variable(img.cuda())
    f_score, f_geometry = model(img)
    print(training_mask)
    print(f_score)
    print(f_geometry)
    break
# Out:
# RuntimeErrorTraceback (most recent call last)
# ~/main.py in <module>()
#       1 for i, (img, score_map, geo_map, training_mask) in enumerate(trainloader):
#       2     img = Variable(img.cuda())
# ----> 3     f_score, f_geometry = model(img)
#       4     print(f_score)
#       5     break
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/model.py in forward(self, images)
#     222     def forward(self,images):
#     223         images = mean_image_subtraction(images)
# --> 224         _, f = self.resnet(images)
#     225         h = f[3]  # bs 2048 w/32 h/32
#     226         g = (self.unpool1(h)) #bs 2048 w/16 h/16
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/model.py in forward(self, x)
#     132         x = self.relu(x)
#     133         x = self.maxpool(x)
# --> 134         x = self.layer1(x)
#     135         f.append(x)
#     136         x = self.layer2(x)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/model.py in forward(self, x)
#      73
#      74         out = self.conv3(out)
# ---> 75         out = self.bn3(out)
#      76
#      77         if self.downsample is not None:
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#      47         return F.batch_norm(
#      48             input, self.running_mean, self.running_var, self.weight, self.bias,
# ---> 49             self.training or not self.track_running_stats, self.momentum, self.eps)
#      50
#      51     def extra_repr(self):
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    1192     return torch.batch_norm(
#    1193         input, weight, bias, running_mean, running_var,
# -> 1194         training, momentum, eps, torch.backends.cudnn.enabled
#    1195     )
#    1196
#
# RuntimeError: cuda runtime error (2) : out of memory at /opt/conda/conda-bld/pytorch_1524584710464/work/aten/src/THC/generic/THCStorage.cu:58
